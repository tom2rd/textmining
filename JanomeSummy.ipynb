# %% [markdown]
# <a href="https://colab.research.google.com/github/tom2rd/textmining/blob/master/JanomeSummy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #LexRankで要約
#
# https://ohke.hateblo.jp/entry/2018/11/17/230000
# を参考に
#
# 実装　日本語もできるらしい　https://github.com/miso-belica/sumy
#
# 形態素解析は　Janomeを利用

# %%
# !pip install sumy tinysegmenter Janome
# Out:
# ...
#      |████████████████████████████████| 92kB 5.4MB/s
# ...
#      |████████████████████████████████| 25.1MB 83.8MB/s
# ...
#      |████████████████████████████████| 10.5MB 33.2MB/s
# ...
#   Stored in directory: /root/.cache/pip/wheels/68/71/2b/6402196bf28012826e507ef7b99df6ebd98cce78bd99023471
# ...
#   Stored in directory: /root/.cache/pip/wheels/5a/4d/a1/510b12c5e65e0b2b3ce539b2af66da0fc57571e528924f4a52
# Successfully built tinysegmenter breadability
# ...

# %%
from janome.analyzer import Analyzer
from janome.charfilter import UnicodeNormalizeCharFilter, RegexReplaceCharFilter
from janome.tokenizer import Tokenizer as JanomeTokenizer  # sumyのTokenizerと名前が被るため
from janome.tokenfilter import POSKeepFilter, ExtractAttributeFilter

text = """そもそも、「小平のために」議論したい人は、的な価値観を持っているのではないかな。の価値観の人だと「市議会や町内会などがあるのに、なんで普通の人が議論しているんだ」と思っていたり、の価値観の人だと「好きな人が勝手にやればよい」なんて思っているような気がします。
そういう価値観を、敢えて明示させることによって、逆にいろんな議論ができると期待するのですが、どうですかね。

もちろん他の価値観に関する議題はあると思います。
例えば、の価値観でいうと、小平市って、飛騨高山の家具職人の人が「なぜこんな立派な木が生えているの？」と驚くくらいの大木が民家の庭先にあったりする。それって、小平市の大きな特長だと思うのだけれど、そういう木が個人の努力（少しは市の援助があるらしい）で保存されているのって、小平の将来を考えると大きな課題なんじゃないかなと思いませんか。
でも、本当の事を言うと、小平市って生活するのにほとんど困らないから、あまり小平市の事を考えてこなかったのが事実です。
でも、最近、近所に高齢者しか住んでいない古い家が多くなってきて、諸々を相談されることが増えてきています。家の修理とか信頼できる工務店が何処にあるのかよく分からないじゃないですか。そういうのを気楽に相談できるところがあるといいなと思うのですが、どうですか。
まず、「小平のために」という文脈で。。シンクロンを動かすということを考えたら。。

本物の論点で実際に、議論することで、何かいい議論の結果を出すというのがいいですね。
2。議論のネタの一つとして、ちょっと古いですが、自治条例を小平市が作った時の検討部会の
課題が乗ってまして、これって、わりと普遍的な議論ネタだと思います。

https://www.city.kodaira.tokyo.jp/kurashi/003/003548.html

第１部会 検討の記録（１）
更新日： 2007年（平成19年）10月3日 　作成部署：企画政策部 政策課
 2。超要約すると、これは、議論の方法や集約に関する議論なんですが。。

こういう今、何かなされている議論に関して、
竹井さんや、松岡さんに、聞いて、リアルに議論するのがいいかと思うんですが
どうでしょうかね？

議論に参加する人を制限せずに、使えるようにするのがいいのでしょうが・・

どう思われますか？？
 
主張：小平の議論ならば、身近な議題が良いと思います。
理由：世界の議論、日本の議論ではなく、小平の議論というならば、とっても身近な問題なのではと思います。そして、小平の議論に参加する人達は、的なメリットよりよも、すぐ結果の分かる個人的なメリットを強く求めているのではないでしょうか？
 < 2。議論を深めるには、色々な考え方のが欲しいですが、多すぎるのもまとまらない？
オープンにするとした場合、実名式なのか、匿名なのかも重要だと思います。
匿名でないと言えないこともあると思うけど、匿名だとに責任がないですね
 < 2。市議会との関係というのは、考慮しなければいけないものだとは思いますが、
市議会内部での議論に関係するというより、今行われている／行われようとしているリアルな活動に対する議論を進めてはいかがでしょうか。単純に議論するのではなく、リアルな活動をしている人にしか分からない論点みたいなものがあるはずで、それに基づいて議論するのが良いと思います。
リアルな議論という意味で、私は、実名のほうが良いかなと思います。損得が関係する話題にはなかなか実名は難しいのかなとは思うけど、「の観点から言えば」こんな損得があり、「の価値観では」こんな損得がある、といったように、シンクロンの利点を上手く活用すれば、そういう議論もできるのではないかと思っているのですが。
僕もそう思います。

そのために、最初のカテゴリーとか
議論ネタを仕込んでおいた方が良いでしょうね
 2。現在進行形の審議会の議事録です。
この中から、本当は議論をピックアップしてくればいいんでしょうね。

https://www.city.kodaira.tokyo.jp/kurashi/index07003004.html
 2。審議会議事録って必要なとき以外見ないですがたしかにネタの宝庫ですね。市議会で議論してることって身近な話題ばかりなのでその意味では議論のネタたくさんあります。最近ではふるさと納税。小平に入るべき税金が２億以上よそに流れ、逆に小平市へ納税されたのは300万円くらいに過ぎない とか…このアンバランスをどうする？
 。こだいらコンシェルジュ的な？
確かにこのネット時代にあって、ネットではわからない情報なのかも…工務店 ホームページないでしょうし… 商工会に加盟してたら 検索には引っ掛かるけど信頼度はわからないですね…
小平市に限らず、どこの市議会でも、産業・経済に関わる議論ってあまり得意ではない印象があります。もともと行政の仕事の範疇がそういうのに向いていないからですが。なので、せいぜい、地場産業の保護とか商店街の振興とか。地場産業も商店街もめぼしいものが無い小平市としては、新規産業を作らざるを得ないはずなんですが、市民レベルでそういうのを議論しても面白いのではないですかね。
高齢者ビジネスですね。小平市はこれから高齢者の割合が急増することは明らかなわけですが、ニーズを必ずしも充足していない。一方で、ビジネスの最前線に居た人が引退して小平市に住んでいるわけです。そのあたり、ちゃんとマッチングできれば、高齢者ビジネスを作れるのではないかなと。
文字数制限に引っかかるので別けて記述します。
①
小平の議論で利用するために、小平の要望とか不満とか小平がこうなったらいいのにっていうビジョンとかを、いろんな人が書き込める場所にできれば、そこから議論は勝手に生まれていくのではないでしょうか？

要望や不満のぶつかり合いのなかで理解が生まれれば良いのかもしれませんね。
②
生活の中で生まれる問題とか疑問とか要望とか、行政に聞いてみたり要望してみたい事があっても行動するはほぼ無いと思います。（不満はあるかもですが、こうなったら良いなって事はまず発信しませんよね）例えば、もっと緑溢れる街にしたいとか、ここの渋滞が酷いとか、もっと魅力的なお店が欲しいとか、そんな要望が書き込めて、それに対してが集まって議論が生まれるようになれば、
街の意識に変化が生まれないかな？
③
既知の問題で既に行政が動いていますとか、こんな理由で実現できないんですっていう理由でもリアクションがあれば、書き込みした人はスッキリした気持ちで生活していけると思うんです。
④
さらに、市議会議員さんとかが参加している公認がとれれば、
そのが行政に届く可能性を感じられるので、書き込み側のモチベーションはあがりませんか？。
市議会議員さん側も、ここでの議論の内容をまとめて○○した実績を選挙活動に活用してもらえればWin-Winの関係になれないなか？（そんな甘くないか・・・）
少なくも自分の要望とかに、回答をくれた人は支持する要素になると思うんだけどな。。。
⑥
もちろん市議会だけでなくいろんな分野の悩みに回答できる人が集まってくれると最高ですね！
バリヤフリーの店が少ないって悩みに対して、バリヤフリーマップ作りましたって回答だったり、こんなお店ないかなって質問に対して回答だったり。営利活動に対してはもう少し考慮が必要ですが。。。

さらにその議論がうまくサマライズされてまとまれば、今の小平が見えるみたいな感じにならないかな？
⑦
この様な活動を、市が主体ではなく、市民が主体で動かす事ができればカッコイイと思うんですよねー

⑤を飛ばしてしましました。
スミマセン。。。
信頼度を付けた　地域用の宣伝アプリ作りましょうかね？＜今の議論の流れと違うか？(笑)
そうそう。。軋轢というか少しストレスというかが、ある方が　盛り上がるんですよね。
そういう利用がいいと思うんです。
。議論はするべきだと思うんですが。。
こと　産業になったら、たぶん、産業（商売）を作っている人が議論するのって
すごく嫌がりますね。　アイディアを出し抜くことが、最初のとっかかりになるので
産業振興は、隠れてやる方が実はいいと思います。少ない人数でリーンスタートアップが。。

議論すればするほど、おもしろいアイディアが、普通のアイディアになりますもんね。
うちの会社のように(笑)
不満から、自分で行動に移すようになると、もっといいですね。

勝手に道端に花を置くみたいなことが許されるっていう実績があれば
みんなするかもしれないですね。
エディブルシティ　みたいな感じになるといいなぁ～
 
。市会議員さんは、複数入ってほしいですね。

政治と議論っていう関係では、PoliPoliっていうアプリがあって
議員さんと、市民をつなげる役割みたいです。
https://www.polipoli.work/

これ実はITの大事な役目だと思うんですよね。。
政治家さんどうしが議論するんじゃなく。。を聞いて、こういう風に議会で発言しました。みたいなこと書き込んでもらえると、面白いと思います。
 
 2。PoliPoli知らなかったー！
議論と政治のテーマだど、かなり近いイメージですねー
Apple限定！！（涙

説明を読むと国政を意識している感じかな？
IT版の目安箱ってイメージかな。
私のイメージはもう少し街に特化した形で、
目安箱というよりは、Yahoo!知恵袋＋Wikiになればって感じですかね。
政治への無関心がちょっとでも解消されればと思ってましたが、PoliPoliも答えになってますね
。そうみたいですね。Facebookの小平CivicTechのグループで、道路の話が前に出た時、計画のページ教えてあげたら、すっきりしたって。。言ってた人がいました。
そういうのは、Botで作れないかな？(笑)　市役所Bot
 2。自分と同じ考えを持っている人がいるって思えれば、もっと行動できると思うんですよね。
最近は、一部の否定的なばかりが注目されて、規制規制みたいになっていますが、
議論と共感で解決できないかなぁって思います。
ネタの宝庫なんですよね。

あれ分析して、見せるだけでも。。面白いと思うんです。

ふるさと納税に関しては、ノーアイディアですが、用水に水を流すためにお金集めるとか
クラウドファンディング的なノリの方が、いいのかもですね。物でおもしろそうなモノが
ないから、コトで集めるっていうのも手かもですよ
そこ、本当にそう思います。

自然の中で、石ころに躓いてこけても、行政のせいにされないけど
都会の道路で、躓くと、行政になんとかして！って言ってしまいますからね。

自己責任と共感で、解決できるといいと僕も思います。
サマライズ機能が、欲しいんですよね。
サマライズの前に論点を抽出するとか。。

Word2VecとTensorflowでできないかな？？

https://ai.googleblog.com/2016/08/text-summarization-with-tensorflow.html

試してみようかな？(笑)
。PoliPoliは大上段過ぎるので、もっと身近な感じのものがいいですよね。

議員　VS　市民　じゃなくて
市民の中の議員　っていう立ち位置での議論がいいな
 2。「議論をする」というイメージが少し違うかもしれませんね。
結論を出そうとするとアイデアはつまらなくなりますが、アイデア出しのフリーディスカッションで終わっても、それはそれで良いのではないでしょうか。少ない人数でリーンスタートアップをするための議論という意味です。アイデアを隠しておきたいという人は議論に参加しないでしょうけど、こんな事をやりたいんだけどアイデアが欲しい！というニーズはあるのでは？
「自己責任」というのは、の価値観の典型的なキーワードだと思うのですが、もちろん、そういう価値観ではない人も多く居るわけです。

例えば、の価値観のだと、
行政の役割と市民の役割を明確にしないと上手くいかないのでは？道路に穴が開いているのを発見したからといって市民が勝手に埋めていいわけではないでしょ。
という事になります。
。このスレッド　別々のことが、いろいろ混ざっている状態になりました
さて、そろそろ、一回、この議論を　可視化できないでしょうか？

中間としてまとめると。
まず、・・で。。。
議論のステージとしては、が出たというところだと思うので

あくまでも、「小平の議論として使ってもらうには？」　
について、を出してもらったと思うんですが
論点を整理してみると。どうなる？
議論をする。
みんなでコミュニケーションをするために議論する。
次に何をするか決めるためにアイディア出しをする。
究極に困っているので、明日何をしたらいいか議論する。
いろんなフェーズがありますから。。
それぞれのフェーズで使えるようなMVPに必要なことを議論するのがいいですね。
2。フリーディスカッションになっているので、完全には論点整理ができないとは思いますが、「小平の議論としてどう使うか」というテーマに対する論点として、
〇議論を行う目的は何か
〇議論に参加する人は誰か
〇どういう分野のテーマに対して議論を行うか
〇具体的な議論のテーマは何か
〇シンクロンをどう使うか、それとも別の方法にするか
あたりが議論になっていたのではないかと思います。
。これ、議論のまとめ　とか　書けるところがあるんですよ。

そこにまとめて見るとどうでしょう？
 2。私もシンクロンを初めて利用したのですが、テーマの設定に工夫が要るのかなというのが感想です。「小平でどう使ってもらうか」というテーマだと、論点がいくつも発生して、一つ一つの論点については議論が不十分になり、まだまとめの段階にはないような気がします。例えば、「議員の皆さんに参加してもらうには」等の具体的なテーマにすると、いろんな価値観の議論ができそうですが。
。それが論点整理では？

大枠→　論点　→　分割して議論　→　ひとつの合意

そういうフローも上手くコントロールできると
良いですよね
なんか、色々発散させてしまってスミマセン。。
この発散をうまくまとめたって感じですね！！
なんとなーくですが、元々の議題「小平でどう使ってもうか？」がシンクロンにマッチしていない様な気がしています。
シンクロンは、かNoの問題に対して色々な価値観で議論する仕組みになっているイメージですかね？
うどん派、蕎麦派　や　犬派、猫派　や　タケノコかキノコなどですね。
マルオさんが上げた出た穴を埋めるか、放っておくかとかも、盛り上がりそうな議題だと思います。
問題を解決する議論をする上では、、Noだけではなく、第3案も欲しい所だと思います。

なので、トップは、問題点＋前提条件の説明
問題に対して、解決案や実行案を複数追加できるようにする。
その案についての,Noを各価値観で議論する感じのIFにすれば、
わりとまとまりそうな気もするんですけど、どうですかね？
議論を進めて行く上で、問題の前提条件に対する質問とかもできるようになるといいですね
確かに、ふわぁっとした設定というよりは、是か非かを問えない課題を問うのに一番マッチしてますね。



問いに継続のというか、関係する議論があるという議論のフローが見えると面白いですね
道路の穴問題について、試しに作ってみました。No.19です。

このテーマで議論をするかどうかはさておき、こんな感じでどうですかね？
 2。まとめのところ、書いてみました。
このまとめの機能を、みんなで、編集していくといいのでは？？
どうですか？

まず、ユーザーに開放するかどうか？どうやってユーザーを増やすか？
その時までに、少しでもカスタマイズするか？ってことを、僕は合意したいのですが。。
どうでしょう？　このままだと、はなこ哲学道場とかには、うけると思いますが
みなさんが議論するという場には使いにくいかと。。
。試しに書いてみました。
けど、”小平の”っていうローカル感は薄いかもですね。
私のイメージだと、下記みたいなイメージです。

タケノコ公園のグランドの真ん中に大きな穴が空いてました。
子供が遊ぶ公園で、誤ってつまずいて怪我をしないように
近くの砂場から砂を取って穴を埋めた所、
公園にいた初老の男性に、勝手に穴を埋めるんじゃないっと怒られました。
私は間違っていたでしょうか？
 2。まとめ機能、人のまとめに手をいれるのは勇気いります。
やっぱりまとめが壁ですね。

この2週間位もんもんと考えて、ここで上がったテーマを解決したら
世の中ちょっと良くなるかもって感じたので、
カスタマイズして、是非公開できたらと思いますけど、
他の方はどう感じているのでしょうか？
まずは、ユーザーに対してどんな議論の場を提供するか？
その場所にどんな価値があるのか？を集まって話してみたいなぁ

"""

# 1行1文となっているため、改行コードで分離
sentences = [t for t in text.split('\n')]
for i in range(2):
    print(sentences[i])
# 転職 Advent Calendar 2016 - Qiitaの14日目となります。 少しポエムも含みます。
# 今年11月にSIerからWebサービスの会社へ転職しました。

# 形態素解析器を作る
analyzer = Analyzer(
    [UnicodeNormalizeCharFilter(), RegexReplaceCharFilter(r'[(\)「」、。]', ' ')],  # ()「」、。は全てスペースに置き換える
    JanomeTokenizer(),
    [POSKeepFilter(['名詞', '形容詞', '副詞', '動詞']), ExtractAttributeFilter('base_form')]  # 名詞・形容詞・副詞・動詞の原型のみ
)

# 抽出された単語をスペースで連結
# 末尾の'。'は、この後使うtinysegmenterで文として分離させるため。
corpus = [' '.join(analyzer.analyze(s)) + '。' for s in sentences]
for i in range(2):
    print(corpus[i])
# 転職 Advent Calendar 2016 - Qiita 14 日 目 なる 少し ポエム 含む。
# 今年 11 月 SIer Web サービス 会社 転職 する。
# Out:
# そもそも、「小平のために」議論したい人は、的な価値観を持っているのではないかな。の価値観の人だと「市議会や町内会などがあるのに、なんで普通の人が議論しているんだ」と思っていたり、の価値観の人だと「好きな人が勝手にやればよい」なんて思っているような気がします。
# そういう価値観を、敢えて明示させることによって、逆にいろんな議論ができると期待するのですが、どうですかね。
# 小平 ため 議論 する 人 的 価値 観 持つ いる の 価値 観 人 市議会 町内 会 ある なんで 普通 人 議論 する いる ん 思う いる 価値 観 人 好き 人 勝手 やる よい 思う いる よう 気 する。
# 価値 観 敢えて 明示 する せる こと 逆 議論 できる 期待 する の どう。

# %% [markdown]
# 要約文の抽出
# 上で生成したコーパスから、sumyで要約文を抽出します。
#
# PlaintextParserは、文字列やファイルから文書を読み込みます (他にもHtmlParserが用意されている)
# Tokenizerには言語を指定する ('english', 'german', 'chinese', 'japanese', 'slovak'または'czech'が選択できる)
# LexRankSummarizerで、LexRankの計算を行い、要約文を抽出します
# stop_wordsプロパティでストップワードを指定する
# callメソッドにparserで解析された文書オブジェクトと、抽出したい文の数を、それぞれ引数に渡す

# %%
from sumy.parsers.plaintext import PlaintextParser
from sumy.nlp.tokenizers import Tokenizer
from sumy.summarizers.lex_rank import LexRankSummarizer

# 連結したcorpusを再度tinysegmenterでトークナイズさせる
parser = PlaintextParser.from_string(''.join(corpus), Tokenizer('japanese'))

# LexRankで要約を2文抽出
summarizer = LexRankSummarizer()
summarizer.stop_words = [' ']  # スペースも1単語として認識されるため、ストップワードにすることで除外する

summary = summarizer(document=parser.document, sentences_count=2)

# 元の文を表示
for sentence in summary:
    print(sentences[corpus.index(sentence.__str__())])
# Out:
# 転職 Advent Calendar 2016 - Qiitaの14日目となります。 少しポエムも含みます。
# 今年11月にSIerからWebサービスの会社へ転職しました。

# %% [markdown]
# Sumy の日本語説明は、ここ　https://githubja.com/miso-belica/sumy
#
# Data構造などがないと、コマンドラインからの処理はできなさそう

# %%
! sumy --help
# Out:
# Sumy - automatic text summarizer.
#
# Usage:
#     sumy (luhn | edmundson | lsa | text-rank | lex-rank | sum-basic | kl) [--length=<length>] [--language=<lang>] [--stopwords=<file_path>] [--format=<format>]
#     sumy (luhn | edmundson | lsa | text-rank | lex-rank | sum-basic | kl) [--length=<length>] [--language=<lang>] [--stopwords=<file_path>] [--format=<format>] --url=<url>
#     sumy (luhn | edmundson | lsa | text-rank | lex-rank | sum-basic | kl) [--length=<length>] [--language=<lang>] [--stopwords=<file_path>] [--format=<format>] --file=<file_path>
#     sumy (luhn | edmundson | lsa | text-rank | lex-rank | sum-basic | kl) [--length=<length>] [--language=<lang>] [--stopwords=<file_path>] [--format=<format>] --text=<text>
#     sumy --version
#     sumy --help
#
# Options:
#     --length=<length>        Length of summarized text. It may be count of sentences
#                              or percentage of input text. [default: 20%]
# ...

# %% [markdown]
# Janome Analyzer の使い方
# https://ohke.hateblo.jp/entry/2017/11/02/230000

# %%
import urllib.request


# 「走れメロス」を青空文庫からダウンロード
url = 'http://www.aozora.gr.jp/cards/000035/files/1567_14913.html'
#url ='https://tom2rd.sakura.ne.jp/wp/2016/03/03/post-531/'
html = ''

with urllib.request.urlopen(url) as response:
    html = response.read().decode('shift_jis')

print(html)
# Out:
# <?xml version="1.0" encoding="Shift_JIS"?>
# <!DOCTYPE html PUBLIC "-//W3C//DTD XHTML 1.1//EN"
#     "http://www.w3.org/TR/xhtml11/DTD/xhtml11.dtd">
# <html xmlns="http://www.w3.org/1999/xhtml" xml:lang="ja" >
# <head>
# 	<meta http-equiv="Content-Type" content="text/html;charset=Shift_JIS" />
# 	<meta http-equiv="content-style-type" content="text/css" />
# 	<link rel="stylesheet" type="text/css" href="../../aozora.css" />
# 	<title>太宰治 走れメロス</title>
# 	<script type="text/javascript" src="../../jquery-1.4.2.min.js"></script>
#   <link rel="Schema.DC" href="http://purl.org/dc/elements/1.1/" />
# 	<meta name="DC.Title" content="走れメロス" />
# 	<meta name="DC.Creator" content="太宰治" />
# 	<meta name="DC.Publisher" content="青空文庫" />
# </head>
# <body>
# <div class="metadata">
# <h1 class="title">走れメロス</h1>
# <h2 class="author">太宰治</h2>
# <br />
# <br />
# </div>
# <div id="contents" style="display:none"></div><div class="main_text"><br />
# ...

# %%
from janome.tokenizer import Tokenizer

tokenizer = Tokenizer()

for token in tokenizer.tokenize(html):
    print(token)
# Out:
# <!	名詞,サ変接続,*,*,*,*,<!,*,*
# DOCTYPE	名詞,固有名詞,組織,*,*,*,DOCTYPE,*,*
#  	記号,空白,*,*,*,*, ,*,*
# html	名詞,固有名詞,組織,*,*,*,html,*,*
# >	名詞,サ変接続,*,*,*,*,>,*,*
#
# 	記号,空白,*,*,*,*,
# ,*,*
# <	名詞,サ変接続,*,*,*,*,<,*,*
# html	名詞,固有名詞,組織,*,*,*,html,*,*
#  	記号,空白,*,*,*,*, ,*,*
# lang	名詞,固有名詞,組織,*,*,*,lang,*,*
# ="	名詞,サ変接続,*,*,*,*,=",*,*
# ja	名詞,一般,*,*,*,*,ja,*,*
# ">	名詞,サ変接続,*,*,*,*,">,*,*
#
# 	記号,空白,*,*,*,*,
# ,*,*
# <	名詞,サ変接続,*,*,*,*,<,*,*
# head	名詞,一般,*,*,*,*,head,*,*
# >	名詞,サ変接続,*,*,*,*,>,*,*
#
# 	記号,空白,*,*,*,*,
# ,*,*
# <	名詞,サ変接続,*,*,*,*,<,*,*
# meta	名詞,固有名詞,組織,*,*,*,meta,*,*
#  	記号,空白,*,*,*,*, ,*,*
# name	名詞,固有名詞,組織,*,*,*,name,*,*
# ="	名詞,サ変接続,*,*,*,*,=",*,*
# google	名詞,一般,*,*,*,*,google,*,*
# -	名詞,サ変接続,*,*,*,*,-,*,*
# site	名詞,一般,*,*,*,*,site,*,*
# -	名詞,サ変接続,*,*,*,*,-,*,*
# verification	名詞,一般,*,*,*,*,verification,*,*
# "	名詞,サ変接続,*,*,*,*,",*,*
#  	記号,空白,*,*,*,*, ,*,*
# content	名詞,固有名詞,組織,*,*,*,content,*,*
# ="	名詞,サ変接続,*,*,*,*,=",*,*
# J	名詞,一般,*,*,*,*,J,*,*
# 7	名詞,数,*,*,*,*,7,*,*
# ...

# %%
from janome.charfilter import *


class MainTextCharFilter(CharFilter):
    """
    開始文字列(start)と終了文字列(end)に挟まれたコンテンツ文字列を返すCharFilterの実装
    青空文庫の場合、<div class="main_text">・・・本文・・・</div><div class="bibliographical_information">なので、
    startには'<div class="main_text">'、endには'<div class="bibliographical_information">'を設定する
    """
    def __init__(self, start, end):
        self.start = start
        self.end = end

    def apply(self, text):
        return text.split(self.start)[1].split(self.end)[0]

# %%
from janome.analyzer import Analyzer


char_filters = [UnicodeNormalizeCharFilter(), # UnicodeをNFKC(デフォルト)で正規化
                MainTextCharFilter('<div class="main_text">', '<div class="bibliographical_information">'), # 本文を抽出
                RegexReplaceCharFilter('<rp>\(.*?\)</rp>', ''), # ルビを削除
                RegexReplaceCharFilter('<.*?>', '')] # HTMLタグを削除

tokenizer = Tokenizer()

analyzer = Analyzer(char_filters, tokenizer)

for token in analyzer.analyze(html):
    print(token)
# Out:
# メロス	名詞,一般,*,*,*,*,メロス,*,*
# は	助詞,係助詞,*,*,*,*,は,ハ,ワ
# 激怒	名詞,サ変接続,*,*,*,*,激怒,ゲキド,ゲキド
# し	動詞,自立,*,*,サ変・スル,連用形,する,シ,シ
# た	助動詞,*,*,*,特殊・タ,基本形,た,タ,タ
# 。	記号,句点,*,*,*,*,。,。,。
# 必ず	副詞,助詞類接続,*,*,*,*,必ず,カナラズ,カナラズ
# 、	記号,読点,*,*,*,*,、,、,、
# かの	連体詞,*,*,*,*,*,かの,カノ,カノ
# 邪智	名詞,一般,*,*,*,*,邪智,ジャチ,ジャチ
# 暴虐	名詞,一般,*,*,*,*,暴虐,ボウギャク,ボーギャク
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# 王	名詞,一般,*,*,*,*,王,オウ,オー
# を	助詞,格助詞,一般,*,*,*,を,ヲ,ヲ
# 除か	動詞,自立,*,*,五段・カ行イ音便,未然形,除く,ノゾカ,ノゾカ
# なけれ	助動詞,*,*,*,特殊・ナイ,仮定形,ない,ナケレ,ナケレ
# ば	助詞,接続助詞,*,*,*,*,ば,バ,バ
# なら	動詞,非自立,*,*,五段・ラ行,未然形,なる,ナラ,ナラ
# ぬ	助動詞,*,*,*,特殊・ヌ,基本形,ぬ,ヌ,ヌ
# と	助詞,格助詞,引用,*,*,*,と,ト,ト
# 決意	名詞,サ変接続,*,*,*,*,決意,ケツイ,ケツイ
# し	動詞,自立,*,*,サ変・スル,連用形,する,シ,シ
# た	助動詞,*,*,*,特殊・タ,基本形,た,タ,タ
# 。	記号,句点,*,*,*,*,。,。,。
# メロス	名詞,一般,*,*,*,*,メロス,*,*
# に	助詞,格助詞,一般,*,*,*,に,ニ,ニ
# は	助詞,係助詞,*,*,*,*,は,ハ,ワ
# 政治	名詞,一般,*,*,*,*,政治,セイジ,セイジ
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# わから	動詞,自立,*,*,五段・ラ行,未然形,わかる,ワカラ,ワカラ
# ぬ	助動詞,*,*,*,特殊・ヌ,基本形,ぬ,ヌ,ヌ
# 。	記号,句点,*,*,*,*,。,。,。
# メロス	名詞,一般,*,*,*,*,メロス,*,*
# は	助詞,係助詞,*,*,*,*,は,ハ,ワ
# ...

# %%
from janome.tokenfilter import *


class NumericReplaceFilter(TokenFilter):
    """
    名詞中の数(漢数字を含む)を全て0に置き換えるTokenFilterの実装
    """
    def apply(self, tokens):
        for token in tokens:
            parts = token.part_of_speech.split(',')
            if (parts[0] == '名詞' and parts[1] == '数'):
                token.surface = '0'
                token.base_form = '0'
                token.reading = 'ゼロ'
                token.phonetic = 'ゼロ'
            yield token

# %%
token_filters = [NumericReplaceFilter(), # 名詞中の漢数字を含む数字を0に置換
                 CompoundNounFilter(), # 名詞が連続する場合は複合名詞にする
                 POSKeepFilter(['名詞', '動詞', '形容詞', '副詞']), # 名詞・動詞・形容詞・副詞のみを取得する
                 LowerCaseFilter()] # 英字は小文字にする

analyzer = Analyzer(char_filters, tokenizer, token_filters)

for token in analyzer.analyze(html):
    print(token)
# Out:
# メロス	名詞,一般,*,*,*,*,メロス,*,*
# 激怒	名詞,サ変接続,*,*,*,*,激怒,ゲキド,ゲキド
# し	動詞,自立,*,*,サ変・スル,連用形,する,シ,シ
# 必ず	副詞,助詞類接続,*,*,*,*,必ず,カナラズ,カナラズ
# 邪智暴虐	名詞,複合,*,*,*,*,邪智暴虐,ジャチボウギャク,ジャチボーギャク
# 王	名詞,一般,*,*,*,*,王,オウ,オー
# 除か	動詞,自立,*,*,五段・カ行イ音便,未然形,除く,ノゾカ,ノゾカ
# なら	動詞,非自立,*,*,五段・ラ行,未然形,なる,ナラ,ナラ
# 決意	名詞,サ変接続,*,*,*,*,決意,ケツイ,ケツイ
# し	動詞,自立,*,*,サ変・スル,連用形,する,シ,シ
# メロス	名詞,一般,*,*,*,*,メロス,*,*
# 政治	名詞,一般,*,*,*,*,政治,セイジ,セイジ
# わから	動詞,自立,*,*,五段・ラ行,未然形,わかる,ワカラ,ワカラ
# メロス	名詞,一般,*,*,*,*,メロス,*,*
# 村	名詞,一般,*,*,*,*,村,ムラ,ムラ
# 牧人	名詞,一般,*,*,*,*,牧人,ボクジン,ボクジン
# 笛	名詞,一般,*,*,*,*,笛,フエ,フエ
# 吹き	動詞,自立,*,*,五段・カ行イ音便,連用形,吹く,フキ,フキ
# 羊	名詞,一般,*,*,*,*,羊,ヒツジ,ヒツジ
# 遊ん	動詞,自立,*,*,五段・バ行,連用タ接続,遊ぶ,アソン,アソン
# 暮し	動詞,自立,*,*,五段・サ行,連用形,暮す,クラシ,クラシ
# 来	動詞,非自立,*,*,カ変・来ル,連用形,来る,キ,キ
# 邪悪	名詞,形容動詞語幹,*,*,*,*,邪悪,ジャアク,ジャアク
# 人一倍	名詞,形容動詞語幹,*,*,*,*,人一倍,ヒトイチバイ,ヒトイチバイ
# 敏感	名詞,形容動詞語幹,*,*,*,*,敏感,ビンカン,ビンカン
# きょう未明メロス	名詞,複合,*,*,*,*,きょう未明メロス,キョウミメイ*,キョーミメイ*
# 村	名詞,一般,*,*,*,*,村,ムラ,ムラ
# 出発	名詞,サ変接続,*,*,*,*,出発,シュッパツ,シュッパツ
# し	動詞,自立,*,*,サ変・スル,連用形,する,シ,シ
# 野	名詞,一般,*,*,*,*,野,ノ,ノ
# ...
